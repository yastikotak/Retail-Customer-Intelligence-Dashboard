# %%
pip install sqlalchemy psycopg2-binary
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --------------- ------------------------ 1.0/2.8 MB 5.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.8 MB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 5.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv(
    r"C:\Users\Yasti\Desktop\Projects\Retail_Customer_Churn_Intelligence\data\cleaned\online_retail_cleaned.csv"
)

df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Revenue  \
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
#
#    IsCancelled  IsReturn
# 0        False     False
# 1        False     False
# 2        False     False
# ...

# %%
engine = create_engine(
    "postgresql+psycopg2://postgres:yasti@11@localhost:5433/retail_customer_churn_db"
)

# %%
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

connection_url = URL.create(
    drivername="postgresql+psycopg2",
    username="postgres",
    password="yasti@11",
    host="localhost",
    port=5433,
    database="retail_customer_churn_db"
)

engine = create_engine(connection_url)

# %%
with engine.connect() as conn:
    print("✅ Connected to PostgreSQL successfully!")
# Out:
# ✅ Connected to PostgreSQL successfully!

# %%
print(df["CustomerID"].dtype)
# Out:
# float64

# %%
# Convert CustomerID to nullable integer
df["CustomerID"] = df["CustomerID"].astype("Int64")

# %%
print(df["CustomerID"].dtype)
# Out:
# Int64

# %%
print(df.columns.tolist())
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'Revenue', 'IsCancelled', 'IsReturn']

# %%
df.columns = df.columns.str.lower()

print(df.columns.tolist())
# Out:
# ['invoiceno', 'stockcode', 'description', 'quantity', 'invoicedate', 'unitprice', 'customerid', 'country', 'revenue', 'iscancelled', 'isreturn']

# %%
df.to_sql(
    "stg_online_retail",
    con=engine,
    if_exists="append",
    index=False,
    chunksize=5000
)
# Out:
# 107641

# %%
print(df.shape)
# Out:
# (536641, 11)
